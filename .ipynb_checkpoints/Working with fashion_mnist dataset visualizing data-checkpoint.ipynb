# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
#! pip install tensorflow==2.0.0-beta1

import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
mnist= tf.keras.datasets.fashion_mnist

# %%
(training_images, training_labels), (test_images, test_labels)=mnist.load_data()

# %% [markdown]
# ### Normalizing data

# %%
training_images= training_images / 255.0
test_images= test_images / 255.0

# %% [markdown]
# # Showing the fashion images

# %%
def img(data):
    '''
    this function to visualizing the images of fashions
    '''
    plt.imshow(data)
    plt.show()

# %%
# unique clothes in dataset
decription = ["t shirt","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %% [markdown]
# # Print the unique clothes in the data set and their pictures

# %%
for i in np.arange(0,10):
    idx = [x[0] for x in np.where(training_labels==i)]
    print(training_labels[idx[0]],'-', decription[i] )
    img(training_images[idx[0]])
# Out:
# 0 - t shirt
# 1 - Trouser
# 2 - Pullover
# 3 - Dress
# 4 - Coat
# 5 - Sandal
# 6 - Shirt
# 7 - Sneaker
# 8 - Bag
# 9 - Ankle boot

# %% [markdown]
# ## Basic Computer Vision with TF

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), 
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), 
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(training_images, training_labels, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.4963 - accuracy: 0.8247
# Epoch 2/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.3728 - accuracy: 0.8657
# Epoch 3/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.3344 - accuracy: 0.8779
# Epoch 4/5
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.3120 - accuracy: 0.8852
# Epoch 5/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.2934 - accuracy: 0.8907

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 50us/sample - loss: 0.3728 - accuracy: 0.8656
# [0.37279950346946716, 0.8656]

# %%
classify = model.predict(test_images)

# %% [markdown]
# # Some prediction of my classification model:

# %% [markdown]
# You shold notice there are some wrong predicts and that because the accurace of training model is maybe equal to 0.86.

# %%
for i in range(20):
    someindx= np.where(classify[i]==max(classify[i]))[0][0]
    print("My model predicted this is===>",decription[someindx])
    img(test_images[i])
# Out:
# My model predicted this is===> Ankle boot
# My model predicted this is===> Pullover
# My model predicted this is===> Trouser
# My model predicted this is===> Trouser
# My model predicted this is===> Shirt
# My model predicted this is===> Trouser
# My model predicted this is===> Coat
# My model predicted this is===> Shirt
# My model predicted this is===> Sandal
# My model predicted this is===> Sneaker
# My model predicted this is===> Coat
# My model predicted this is===> Sandal
# My model predicted this is===> Sandal
# My model predicted this is===> Dress
# My model predicted this is===> Coat
# My model predicted this is===> Trouser
# My model predicted this is===> Pullover
# My model predicted this is===> Pullover
# My model predicted this is===> Bag
# My model predicted this is===> t shirt
